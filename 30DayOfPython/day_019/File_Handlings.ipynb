# %% [markdown]
# Day 19 : 30 Days of Python Programming Exercises

# %%
# importing the required libraries
import re
import json
import csv

# %% [markdown]
# Exercises: Level 1

# %% [markdown]
# 1. Write a function which count number of lines and number of words in a text. All the files are in the data the folder:

# %% [markdown]
# a) Read obama_speech.txt file and count number of lines and words
#
# b) Read michelle_obama_speech.txt file and count number of lines and words
#
# c) Read donald_speech.txt file and count number of lines and words
#
# d) Read melina_trump_speech.txt file and count number of lines and words

# %%
def read_count_lines(x):
    with open (x) as d:
        lines_list = d.readlines()
        no_of_lines = len(lines_list)

        no_words = 0
        for i in lines_list :
            doc_words = re.sub(r'[^\w\s]','', i)
            words = doc_words.split()
            no_words += len(words)
            

        print('The number of lines in the document is ', no_of_lines)
        print('The number of words in the document is ', no_words)

print('Obama Speech')
read_count_lines('./data/obama_speech.txt')
print('Michelle Obama Speech')
read_count_lines('./data/michelle_obama_speech.txt')
print('Trump Speech')
read_count_lines('./data/donald_speech.txt')
print('Melina Trump Speech')
read_count_lines('./data/melina_trump_speech.txt')
# Out:
# Obama Speech
# The number of lines in the document is  66
# The number of words in the document is  2377
# Michelle Obama Speech
# The number of lines in the document is  83
# The number of words in the document is  2203
# Trump Speech
# The number of lines in the document is  48
# The number of words in the document is  1259
# Melina Trump Speech
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[32], line 23
#      21 read_count_lines('./data/donald_speech.txt')
#      22 print('Melina Trump Speech')
# ---> 23 read_count_lines('./data/melina_trump_speech.txt')
#
# Cell In[32], line 2, in read_count_lines(x)
#       1 def read_count_lines(x):
# ----> 2     with open (x) as d:
#       3         lines_list = d.readlines()
#       4         no_of_lines = len(lines_list)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/melina_trump_speech.txt'

# %%
def count_words_lines(file):
    '''Counts the number of lines and words in a file'''
    with open(file) as f:
        lines = f.readlines()
        words = []
        for line in lines:
            # removing all characters that are not whitespace or alphanumeric using regex
            line = re.sub(r'[^\w\s]','',line)
            words.extend(line.split())
    print(f'The number of lines and words in the file are {len(lines)} and {len(words)} respectively')
count_words_lines('melania_trump_speech.txt')
count_words_lines('donald_speech.txt')
count_words_lines('michelle_obama_speech.txt')
count_words_lines('obama_speech.txt')

# %%
def most_spoken_languages(file,n):
    '''
    Takes a filepath and an integer,n as arguments and returns the n most spoken languages in the world
    '''
    with open(file) as f:
        list = json.loads(f.read())
    # looping to get dict of languages
    languages = []
    for i in range(len(list)):
        languages.extend(list[i]['languages'])
    lang = {}
    for language in languages:
        lang[language] = lang.get(language,0) + 1
    # sorting the list of the tuples to get the most spoken languages
    sorted_lang = sorted(lang.items(), key= lambda x:x[1],reverse=True) # contains the languages arranged based on values
    result = [(item[1],item[0]) for item in sorted_lang]
    return result[:n]
print(most_spoken_languages('countries_data.json',10))
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[22], line 18
#      16     result = [(item[1],item[0]) for item in sorted_lang]
#      17     return result[:n]
# ---> 18 print(most_spoken_languages('countries_data.json',10))
#      19 print(most_spoken_languages('countries_data.json',3))
#
# Cell In[22], line 6, in most_spoken_languages(file, n)
#       2 '''
#       3 Takes a filepath and an integer,n as arguments and returns the n most spoken languages in the world
#       4 '''
#       5 with open(file) as f:
# ----> 6     list = json.loads(f.read())
#       7 # looping to get dict of languages
#       8 languages = []
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\encodings\cp1252.py:23, in IncrementalDecoder.decode(self, input, final)
#      22 def decode(self, input, final=False):
# ---> 23     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 50888: character maps to <undefined>

# %%
import json
def most_spoken_languages(filename,countries):
    file = open(filename , encoding="UTF8")
    Lang_dict =json.loads(file.read())
    languages = []
    for i in range(len(Lang_dict)):
        languages.extend(Lang_dict[i]['languages'])
    lang = {}
    for language in languages:
        lang[language] = lang.get(language,0) + 1
    sorted_lang = sorted(lang.items(), key= lambda x:x[1],reverse=True)
    top_langs = []
    for i in range(countries):
      top_langs.append(sorted_lang[i])
    return top_langs

print(most_spoken_languages('./data/countries_data.json', 10))
print(most_spoken_languages('./data/countries_data.json', 3))
# Out:
# [('English', 91), ('French', 45), ('Arabic', 25), ('Spanish', 24), ('Portuguese', 9), ('Russian', 9), ('Dutch', 8), ('German', 7), ('Chinese', 5), ('Serbian', 4)]
# [('English', 91), ('French', 45), ('Arabic', 25)]

# %%
def most_populated_countries(filename,countries):
    file = open(filename , encoding="UTF8")
    Lang_dict =json.loads(file.read())
    population = {}
    for i in range(len(Lang_dict)):
        keys = Lang_dict[i]['name']
        values = Lang_dict[i]['population']
        population[keys] = values
    sorted_pop = dict(sorted(population.items(), key= lambda x:x[1],reverse=True))

    most_pop = []
    for i in list(sorted_pop.items()) [:countries] :
        most_pop.append({"Country" : i[0], "Population" : i[1]})
    return most_pop

print(most_populated_countries('./data/countries_data.json', 10))
most_populated_countries('./data/countries_data.json', 3)
# Out:
# [{'Country': 'China', 'Population': 1377422166}, {'Country': 'India', 'Population': 1295210000}, {'Country': 'United States of America', 'Population': 323947000}, {'Country': 'Indonesia', 'Population': 258705000}, {'Country': 'Brazil', 'Population': 206135893}, {'Country': 'Pakistan', 'Population': 194125062}, {'Country': 'Nigeria', 'Population': 186988000}, {'Country': 'Bangladesh', 'Population': 161006790}, {'Country': 'Russian Federation', 'Population': 146599183}, {'Country': 'Japan', 'Population': 126960000}]
# [{'Country': 'China', 'Population': 1377422166},
#  {'Country': 'India', 'Population': 1295210000},
#  {'Country': 'United States of America', 'Population': 323947000}]

# %%
with open ('./data/email_exchanges_big.txt') as file:
    emails = file.readlines()
email_list = []
for i in emails:
    email_list.extend(re.findall('[a-zA-Z0-9]\S*@\S*[a-zA-Z]', i))
email_list[:]
# Out:
# ['stephen.marquard@uct.ac.za',
#  'postmaster@collab.sakaiproject.org',
#  '200801051412.m05ECIaH010327@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'stephen.marquard@uct.ac.za',
#  'source@collab.sakaiproject.org',
#  'stephen.marquard@uct.ac.za',
#  'stephen.marquard@uct.ac.za',
#  'louis@media.berkeley.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801042308.m04N8v6O008125@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'louis@media.berkeley.edu',
#  'source@collab.sakaiproject.org',
#  'louis@media.berkeley.edu',
#  'louis@media.berkeley.edu',
#  'zqian@umich.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801042109.m04L92hb007923@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'zqian@umich.edu',
#  'rjlowe@iupui.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801042044.m04Kiem3007881@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'rjlowe@iupui.edu',
#  'source@collab.sakaiproject.org',
#  'rjlowe@iupui.edu',
#  'rjlowe@iupui.edu',
#  'zqian@umich.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801042001.m04K1cO0007738@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'zqian@umich.edu',
#  'zqian@umich.edu',
#  'rjlowe@iupui.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801041948.m04JmdwO007705@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'rjlowe@iupui.edu',
#  'source@collab.sakaiproject.org',
#  'rjlowe@iupui.edu',
#  'rjlowe@iupui.edu',
#  'cwen@iupui.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801041635.m04GZQGZ007313@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'cwen@iupui.edu',
#  'source@collab.sakaiproject.org',
#  'cwen@iupui.edu',
#  'cwen@iupui.edu',
#  'hu2@iupui.edu',
#  'cwen@iupui.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801041633.m04GX6eG007292@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'cwen@iupui.edu',
#  'source@collab.sakaiproject.org',
#  'cwen@iupui.edu',
#  'cwen@iupui.edu',
#  'hu2@iupui.edu',
#  'gsilver@umich.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801041611.m04GB1Lb007221@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'gsilver@umich.edu',
#  'source@collab.sakaiproject.org',
#  'gsilver@umich.edu',
#  'gsilver@umich.edu',
#  'gsilver@umich.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801041610.m04GA5KP007209@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'gsilver@umich.edu',
#  'source@collab.sakaiproject.org',
#  'gsilver@umich.edu',
#  'gsilver@umich.edu',
#  'zqian@umich.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801041609.m04G9EuX007197@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'zqian@umich.edu',
#  'gsilver@umich.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801041608.m04G8d7w007184@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'gsilver@umich.edu',
#  'source@collab.sakaiproject.org',
#  'gsilver@umich.edu',
#  'gsilver@umich.edu',
#  'wagnermr@iupui.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801041537.m04Fb6Ci007092@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'wagnermr@iupui.edu',
#  'source@collab.sakaiproject.org',
#  'wagnermr@iupui.edu',
#  'wagnermr@iupui.edu',
#  'zqian@umich.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801041515.m04FFv42007050@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'zqian@umich.edu',
#  'antranig@caret.cam.ac.uk',
#  'postmaster@collab.sakaiproject.org',
#  '200801041502.m04F21Jo007031@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'antranig@caret.cam.ac.uk',
#  'source@collab.sakaiproject.org',
#  'antranig@caret.cam.ac.uk',
#  'antranig@caret.cam.ac.uk',
#  'gopal.ramasammycook@gmail.com',
#  'postmaster@collab.sakaiproject.org',
#  '200801041403.m04E3psW006926@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'gopal.ramasammycook@gmail.com',
#  'source@collab.sakaiproject.org',
#  'gopal.ramasammycook@gmail.com',
#  'gopal.ramasammycook@gmail.com',
#  'david.horwitz@uct.ac.za',
#  'postmaster@collab.sakaiproject.org',
#  '200801041200.m04C0gfK006793@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'david.horwitz@uct.ac.za',
#  'source@collab.sakaiproject.org',
#  'david.horwitz@uct.ac.za',
#  'david.horwitz@uct.ac.za',
#  'david.horwitz@uct.ac.za',
#  'dhorwitz@david-horwitz-6:~/branchManagemnt/sakai_2-5-x',
#  'dhorwitz@david-horwitz-6:~/branchManagemnt/sakai_2-5-x',
#  'david.horwitz@uct.ac.za',
#  'postmaster@collab.sakaiproject.org',
#  '200801041106.m04B6lK3006677@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'david.horwitz@uct.ac.za',
#  'source@collab.sakaiproject.org',
#  'david.horwitz@uct.ac.za',
#  'david.horwitz@uct.ac.za',
#  'david.horwitz@uct.ac.za',
#  'postmaster@collab.sakaiproject.org',
#  '200801040947.m049lUxo006517@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'david.horwitz@uct.ac.za',
#  'source@collab.sakaiproject.org',
#  'david.horwitz@uct.ac.za',
#  'david.horwitz@uct.ac.za',
#  'josrodri@iupui.edu',
#  'dhorwitz@david-horwitz-6:~/branchManagemnt/sakai_2-5-x',
#  'david.horwitz@uct.ac.za',
#  'postmaster@collab.sakaiproject.org',
#  '200801040932.m049W2i5006493@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'david.horwitz@uct.ac.za',
#  'source@collab.sakaiproject.org',
#  'david.horwitz@uct.ac.za',
#  'david.horwitz@uct.ac.za',
#  'josrodri@iupui.edu',
#  'dhorwitz@david-horwitz-6:~/branchManagemnt/sakai_2-5-x',
#  'stephen.marquard@uct.ac.za',
#  'postmaster@collab.sakaiproject.org',
#  '200801040905.m0495rWB006420@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'stephen.marquard@uct.ac.za',
#  'source@collab.sakaiproject.org',
#  'stephen.marquard@uct.ac.za',
#  'stephen.marquard@uct.ac.za',
#  'louis@media.berkeley.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801040023.m040NpCc005473@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'louis@media.berkeley.edu',
#  'source@collab.sakaiproject.org',
#  'louis@media.berkeley.edu',
#  'louis@media.berkeley.edu',
#  'louis@media.berkeley.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801032216.m03MGhDa005292@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'louis@media.berkeley.edu',
#  'source@collab.sakaiproject.org',
#  'louis@media.berkeley.edu',
#  'louis@media.berkeley.edu',
#  'ray@media.berkeley.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801032205.m03M5Ea7005273@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'ray@media.berkeley.edu',
#  'source@collab.sakaiproject.org',
#  'ray@media.berkeley.edu',
#  'ray@media.berkeley.edu',
#  'cwen@iupui.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801032133.m03LX3gG005191@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'cwen@iupui.edu',
#  'source@collab.sakaiproject.org',
#  'cwen@iupui.edu',
#  'cwen@iupui.edu',
#  'cwen@iupui.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801032127.m03LRUqH005177@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'cwen@iupui.edu',
#  'source@collab.sakaiproject.org',
#  'cwen@iupui.edu',
#  'cwen@iupui.edu',
#  'wagnermr@iupui.edu',
#  'cwen@iupui.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801032122.m03LMFo4005148@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'cwen@iupui.edu',
#  'source@collab.sakaiproject.org',
#  'cwen@iupui.edu',
#  'cwen@iupui.edu',
#  'wagnermr@iupui.edu',
#  'ray@media.berkeley.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801032054.m03KsIIF005054@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'ray@media.berkeley.edu',
#  'source@collab.sakaiproject.org',
#  'ray@media.berkeley.edu',
#  'ray@media.berkeley.edu',
#  'cwen@iupui.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801032052.m03KqOsp005029@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'cwen@iupui.edu',
#  'source@collab.sakaiproject.org',
#  'cwen@iupui.edu',
#  'cwen@iupui.edu',
#  'cwen@iupui.edu',
#  'zqian@umich.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801032025.m03KPvQi004928@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'zqian@umich.edu',
#  'cwen@iupui.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801032024.m03KOBAp004915@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'cwen@iupui.edu',
#  'source@collab.sakaiproject.org',
#  'cwen@iupui.edu',
#  'cwen@iupui.edu',
#  'cwen@iupui.edu',
#  'cwen@iupui.edu',
#  'cwen@iupui.edu',
#  'cwen@iupui.edu',
#  'cwen@iupui.edu',
#  'cwen@iupui.edu',
#  'wagnermr@iupui.edu',
#  'rjlowe@iupui.edu',
#  'zqian@umich.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801032022.m03KMFfc004903@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'zqian@umich.edu',
#  'zqian@umich.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801031930.m03JUkCZ004841@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'zqian@umich.edu',
#  'zqian@umich.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801031849.m03InajQ004753@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'zqian@umich.edu',
#  'mmmay@indiana.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801031837.m03IbPY7004727@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'mmmay@indiana.edu',
#  'source@collab.sakaiproject.org',
#  'mmmay@indiana.edu',
#  'mmmay@indiana.edu',
#  'wagnermr@iupui.edu',
#  'cwen@iupui.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801031819.m03IJA7j004645@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'cwen@iupui.edu',
#  'source@collab.sakaiproject.org',
#  'cwen@iupui.edu',
#  'cwen@iupui.edu',
#  'cwen@iupui.edu',
#  'zqian@umich.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801031815.m03IFbue004618@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'zqian@umich.edu',
#  'zqian@umich.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801031812.m03ICrFH004606@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'zqian@umich.edu',
#  'zqian@umich.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801031807.m03I7eg2004582@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'zqian@umich.edu',
#  'cwen@iupui.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801031806.m03I6g8Y004558@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'cwen@iupui.edu',
#  'source@collab.sakaiproject.org',
#  'cwen@iupui.edu',
#  'cwen@iupui.edu',
#  'zqian@umich.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801031806.m03I6pEt004570@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'zqian@umich.edu',
#  'cwen@iupui.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801031804.m03I4lVU004546@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'cwen@iupui.edu',
#  'source@collab.sakaiproject.org',
#  'cwen@iupui.edu',
#  'cwen@iupui.edu',
#  'ray@media.berkeley.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801031747.m03HlB1h004532@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'ray@media.berkeley.edu',
#  'source@collab.sakaiproject.org',
#  'ray@media.berkeley.edu',
#  'ray@media.berkeley.edu',
#  'zqian@umich.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801031730.m03HUeEg004479@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'zqian@umich.edu',
#  'zqian@umich.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801031726.m03HQUQ6004462@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'zqian@umich.edu',
#  'zqian@umich.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801031723.m03HNIp2004441@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'zqian@umich.edu',
#  'cwen@iupui.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801031643.m03Gh1r2004386@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'cwen@iupui.edu',
#  'source@collab.sakaiproject.org',
#  'cwen@iupui.edu',
#  'cwen@iupui.edu',
#  'zqian@umich.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801031627.m03GR5UM004357@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'zqian@umich.edu',
#  'gopal.ramasammycook@gmail.com',
#  'postmaster@collab.sakaiproject.org',
#  '200801031610.m03GAkl3004326@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'gopal.ramasammycook@gmail.com',
#  'source@collab.sakaiproject.org',
#  'gopal.ramasammycook@gmail.com',
#  'gopal.ramasammycook@gmail.com',
#  'gsilver@umich.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801031528.m03FSpXg004260@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'gsilver@umich.edu',
#  'source@collab.sakaiproject.org',
#  'gsilver@umich.edu',
#  'gsilver@umich.edu',
#  'gsilver@umich.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801031526.m03FQhmF004248@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'gsilver@umich.edu',
#  'source@collab.sakaiproject.org',
#  'gsilver@umich.edu',
#  'gsilver@umich.edu',
#  'stuart.freeman@et.gatech.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801031521.m03FLXtP004230@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'stuart.freeman@et.gatech.edu',
#  'source@collab.sakaiproject.org',
#  'stuart.freeman@et.gatech.edu',
#  'stuart.freeman@et.gatech.edu',
#  'stuart@mothra:pts/2)----------------------------------------------------------------------(/home/stuart/src/sakai_2-4-x/polls',
#  'stuart@mothra:pts/2)----------------------------------------------------------------------(/home/stuart/src/sakai_2-4-x/polls',
#  'david.horwitz@uct.ac.za',
#  'stuart@mothra:pts/2)----------------------------------------------------------------------(/home/stuart/src/sakai_2-4-x/polls',
#  'stuart@mothra:pts/2)----------------------------------------------------------------------(/home/stuart/src/sakai_2-4-x/polls',
#  'david.horwitz@uct.ac.za',
#  'stuart@mothra:pts/2)----------------------------------------------------------------------(/home/stuart/src/sakai_2-4-x/polls',
#  'stuart@mothra:pts/2)----------------------------------------------------------------------(/home/stuart/src/sakai_2-4-x/polls',
#  'david.horwitz@uct.ac.za',
#  'zqian@umich.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801031519.m03FJsfm004218@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'zqian@umich.edu',
#  'gsilver@umich.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801031506.m03F6Ctn004182@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'gsilver@umich.edu',
#  'source@collab.sakaiproject.org',
#  'gsilver@umich.edu',
#  'gsilver@umich.edu',
#  'gsilver@umich.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801031505.m03F534R004169@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'gsilver@umich.edu',
#  'source@collab.sakaiproject.org',
#  'gsilver@umich.edu',
#  'gsilver@umich.edu',
#  'gsilver@umich.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801031503.m03F3cRt004144@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'gsilver@umich.edu',
#  'source@collab.sakaiproject.org',
#  'gsilver@umich.edu',
#  'gsilver@umich.edu',
#  'zqian@umich.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801031501.m03F11ZP004123@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'zqian@umich.edu',
#  'wagnermr@iupui.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801031429.m03ETqAT004022@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'wagnermr@iupui.edu',
#  'source@collab.sakaiproject.org',
#  'wagnermr@iupui.edu',
#  'wagnermr@iupui.edu',
#  'stuart.freeman@et.gatech.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801031423.m03ENc58004008@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'stuart.freeman@et.gatech.edu',
#  'source@collab.sakaiproject.org',
#  'stuart.freeman@et.gatech.edu',
#  'stuart.freeman@et.gatech.edu',
#  'stuart@mothra:pts/2)--------------------------------------------------(/home/stuart/src/sakai_2-4-x/reference/docs/conversion',
#  'stuart@mothra:pts/2)--------------------------------------------------(/home/stuart/src/sakai_2-4-x/reference/docs/conversion',
#  'stuart@mothra:pts/2)--------------------------------------------------(/home/stuart/src/sakai_2-4-x/reference/docs/conversion',
#  'stuart@mothra:pts/2)--------------------------------------------------(/home/stuart/src/sakai_2-4-x/reference/docs/conversion',
#  'cwen@iupui.edu',
#  'tnguyen@iupui.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801031420.m03EKxOB003996@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'tnguyen@iupui.edu',
#  'source@collab.sakaiproject.org',
#  'tnguyen@iupui.edu',
#  'tnguyen@iupui.edu',
#  'stuart.freeman@et.gatech.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801031414.m03EEOKY003968@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'stuart.freeman@et.gatech.edu',
#  'source@collab.sakaiproject.org',
#  'stuart.freeman@et.gatech.edu',
#  'stuart.freeman@et.gatech.edu',
#  'stuart@mothra:pts/2)------------------------------------------------------------------(/home/stuart/src/sakai_2-4-x/gradebook',
#  'stuart@mothra:pts/2)------------------------------------------------------------------(/home/stuart/src/sakai_2-4-x/gradebook',
#  'cwen@iupui.edu',
#  'stuart@mothra:pts/2)------------------------------------------------------------------(/home/stuart/src/sakai_2-4-x/gradebook',
#  'stuart@mothra:pts/2)------------------------------------------------------------------(/home/stuart/src/sakai_2-4-x/gradebook',
#  'wagnermr@iupui.edu',
#  'cwen@iupui.edu',
#  'wagnermr@iupui.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801031412.m03ECEFD003956@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'wagnermr@iupui.edu',
#  'source@collab.sakaiproject.org',
#  'wagnermr@iupui.edu',
#  'wagnermr@iupui.edu',
#  'gopal.ramasammycook@gmail.com',
#  'postmaster@collab.sakaiproject.org',
#  '200801031342.m03DgeVK003283@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'gopal.ramasammycook@gmail.com',
#  'source@collab.sakaiproject.org',
#  'gopal.ramasammycook@gmail.com',
#  'gopal.ramasammycook@gmail.com',
#  'ray@media.berkeley.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801022345.m02NjcHH001850@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'ray@media.berkeley.edu',
#  'source@collab.sakaiproject.org',
#  'ray@media.berkeley.edu',
#  'ray@media.berkeley.edu',
#  'ray@media.berkeley.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801022308.m02N8fmL001796@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'ray@media.berkeley.edu',
#  'source@collab.sakaiproject.org',
#  'ray@media.berkeley.edu',
#  'ray@media.berkeley.edu',
#  'zqian@umich.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801022203.m02M3QKD001687@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'zqian@umich.edu',
#  'wagnermr@iupui.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801022201.m02M15vH001675@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'wagnermr@iupui.edu',
#  'source@collab.sakaiproject.org',
#  'wagnermr@iupui.edu',
#  'wagnermr@iupui.edu',
#  'stuart.freeman@et.gatech.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801022159.m02LxOsg001648@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'stuart.freeman@et.gatech.edu',
#  'source@collab.sakaiproject.org',
#  'stuart.freeman@et.gatech.edu',
#  'stuart.freeman@et.gatech.edu',
#  'stuart@mothra:pts/5)-------------------------------------------------------------------------(/home/stuart/src/sakai_2-4-x/util',
#  'stuart@mothra:pts/5)-------------------------------------------------------------------------(/home/stuart/src/sakai_2-4-x/util',
#  'joshua.ryan@asu.edu',
#  'chmaurer@iupui.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801022153.m02LrhrH001632@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'chmaurer@iupui.edu',
#  'source@collab.sakaiproject.org',
#  'chmaurer@iupui.edu',
#  'chmaurer@iupui.edu',
#  'stuart.freeman@et.gatech.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801022152.m02LqN8o001620@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'stuart.freeman@et.gatech.edu',
#  'source@collab.sakaiproject.org',
#  'stuart.freeman@et.gatech.edu',
#  'stuart.freeman@et.gatech.edu',
#  'stuart@mothra:pts/5)---------------------------------------------------------------------(/home/stuart/src/sakai_2-4-x/mailtool',
#  'stuart@mothra:pts/5)---------------------------------------------------------------------(/home/stuart/src/sakai_2-4-x/mailtool',
#  'kimsooil@bu.edu',
#  'stuart@mothra:pts/5)---------------------------------------------------------------------(/home/stuart/src/sakai_2-4-x/mailtool',
#  'stuart@mothra:pts/5)---------------------------------------------------------------------(/home/stuart/src/sakai_2-4-x/mailtool',
#  'ian@caret.cam.ac.uk',
#  'rjlowe@iupui.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801022050.m02KoD1g001526@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'rjlowe@iupui.edu',
#  'source@collab.sakaiproject.org',
#  'rjlowe@iupui.edu',
#  'rjlowe@iupui.edu',
#  'zqian@umich.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801022026.m02KQLMk001504@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'zqian@umich.edu',
#  'rjlowe@iupui.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801022018.m02KIxMC001487@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'rjlowe@iupui.edu',
#  'source@collab.sakaiproject.org',
#  'rjlowe@iupui.edu',
#  'rjlowe@iupui.edu',
#  'rjlowe@iupui.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801021934.m02JY7iK001434@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'rjlowe@iupui.edu',
#  'source@collab.sakaiproject.org',
#  'rjlowe@iupui.edu',
#  'rjlowe@iupui.edu',
#  'zqian@umich.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801021755.m02HtJKE001310@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'source@collab.sakaiproject.org',
#  'zqian@umich.edu',
#  'zqian@umich.edu',
#  'rjlowe@iupui.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801021752.m02Hqk8q001298@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'rjlowe@iupui.edu',
#  'source@collab.sakaiproject.org',
#  'rjlowe@iupui.edu',
#  'rjlowe@iupui.edu',
#  'rjlowe@iupui.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801021612.m02GC0dc001119@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'rjlowe@iupui.edu',
#  'source@collab.sakaiproject.org',
#  'rjlowe@iupui.edu',
#  'rjlowe@iupui.edu',
#  'rjlowe@iupui.edu',
#  'postmaster@collab.sakaiproject.org',
#  '200801021608.m02G85Mp001097@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'rjlowe@iupui.edu',
#  'source@collab.sakaiproject.org',
#  'rjlowe@iupui.edu',
#  'rjlowe@iupui.edu',
#  'david.horwitz@uct.ac.za',
#  'postmaster@collab.sakaiproject.org',
#  '200801021452.m02Eqwdg001017@nakamura.uits.iupui.edu',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'source@collab.sakaiproject.org',
#  'apache@localhost',
#  'source@collab.sakaiproject.org',
#  'david.horwitz@uct.ac.za',
#  'source@collab.sakaiproject.org',
#  'david.horwitz@uct.ac.za',
#  ...]

# %%
def find_most_common_words(filename,top_words):
    with open(filename) as file:
        lines = file.readlines()
    words = []
    for line in lines:
        line = re.sub(r'[^\w\s]','',line)
        line_no_num = re.sub(r'\d','',line)
        words.extend(line_no_num.split())
    words_dict = {}
    for word in words:
        words_dict[word] = words_dict.get(word,0) + 1
    words_sorted = sorted(words_dict.items(),key=lambda x:x[1],reverse=True)
    result = [(word[1],word[0]) for word in words_sorted]
    return result[:top_words]

find_most_common_words('./sample.txt', 10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[31], line 16
#      13     result = [(word[1],word[0]) for word in words_sorted]
#      14     return result[:top_words]
# ---> 16 find_most_common_words('./sample.txt', 10)
#
# Cell In[31], line 2, in find_most_common_words(filename, top_words)
#       1 def find_most_common_words(filename,top_words):
# ----> 2     with open(filename) as file:
#       3         lines = file.readlines()
#       4     words = []
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: './sample.txt'
